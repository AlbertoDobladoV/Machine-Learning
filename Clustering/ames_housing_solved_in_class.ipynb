# %% [markdown]
# # The Ames housing dataset
#
# The <a href="http://jse.amstat.org/v19n3/decock.pdf">**Ames Housing dataset**</a> was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset. It is a common <a href="https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview">**Kaggle competition**</a> that is usually used to explain advanced regression techniques.
#
# Here's a brief version of what you'll find in the data description file (<code>ames_housing_description.txt</code>).
#
# * Feature variables:
#     * **MSSubClass** : The building class
#     * **MSZoning** : The general zoning classification
#     * **LotFrontage** : Linear feet of street connected to property
#     * **LotArea** : Lot size in square feet
#     * **Street** : Type of road access
#     * **Alley** : Type of alley access
#     * **LotShape** : General shape of property
#     * **LandContour** : Flatness of the property
#     * **Utilities** : Type of utilities available
#     * **LotConfig** : Lot configuration
#     * **LandSlope** : Slope of property
#     * **Neighborhood** : Physical locations within Ames city limits
#     * **Condition1** : Proximity to main road or railroad
#     * **Condition2** : Proximity to main road or railroad (if a second is present)
#     * **BldgType** : Type of dwelling
#     * **HouseStyle** : Style of dwelling
#     * **OverallQual** : Overall material and finish quality
#     * **OverallCond** : Overall condition rating
#     * **YearBuilt** : Original construction date
#     * **YearRemodAdd** : Remodel date
#     * **RoofStyle** : Type of roof
#     * **RoofMatl** : Roof material
#     * **Exterior1st** : Exterior covering on house
#     * **Exterior2nd** : Exterior covering on house (if more than one material)
#     * **MasVnrType** : Masonry veneer type
#     * **MasVnrArea** : Masonry veneer area in square feet
#     * **ExterQual** : Exterior material quality
#     * **ExterCond** : Present condition of the material on the exterior
#     * **Foundation** : Type of foundation
#     * **BsmtQual** : Height of the basement
#     * **BsmtCond** : General condition of the basement
#     * **BsmtExposure** : Walkout or garden level basement walls
#     * **BsmtFinType1** : Quality of basement finished area
#     * **BsmtFinSF1** : Type 1 finished square feet
#     * **BsmtFinType2** : Quality of second finished area (if present)
#     * **BsmtFinSF2** : Type 2 finished square feet
#     * **BsmtUnfSF** : Unfinished square feet of basement area
#     * **TotalBsmtSF** : Total square feet of basement area
#     * **Heating** : Type of heating
#     * **HeatingQC** : Heating quality and condition
#     * **CentralAir** : Central air conditioning
#     * **Electrical** : Electrical system
#     * **1stFlrSF** : First Floor square feet
#     * **2ndFlrSF** : Second floor square feet
#     * **LowQualFinSF** : Low quality finished square feet (all floors)
#     * **GrLivArea** : Above grade (ground) living area square feet
#     * **BsmtFullBath** : Basement full bathrooms
#     * **BsmtHalfBath** : Basement half bathrooms
#     * **FullBath** : Full bathrooms above grade
#     * **HalfBath** : Half baths above grade
#     * **Bedroom** : Number of bedrooms above basement level
#     * **Kitchen** : Number of kitchens
#     * **KitchenQual** : Kitchen quality
#     * **TotRmsAbvGrd** : Total rooms above grade (does not include bathrooms)
#     * **Functional** : Home functionality rating
#     * **Fireplaces** : Number of fireplaces
#     * **FireplaceQu** : Fireplace quality
#     * **GarageType** : Garage location
#     * **GarageYrBlt** : Year garage was built
#     * **GarageFinish** : Interior finish of the garage
#     * **GarageCars** : Size of garage in car capacity
#     * **GarageArea** : Size of garage in square feet
#     * **GarageQual** : Garage quality
#     * **GarageCond** : Garage condition
#     * **PavedDrive** : Paved driveway
#     * **WoodDeckSF** : Wood deck area in square feet
#     * **OpenPorchSF** : Open porch area in square feet
#     * **EnclosedPorch** : Enclosed porch area in square feet
#     * **3SsnPorch** : Three season porch area in square feet
#     * **ScreenPorch** : Screen porch area in square feet
#     * **PoolArea** : Pool area in square feet
#     * **PoolQC** : Pool quality
#     * **Fence** : Fence quality
#     * **MiscFeature** : Miscellaneous feature not covered in other categories
#     * **MiscVal** : Value of miscellaneous feature in \$
#     * **MoSold** : Month Sold
#     * **YrSold** : Year Sold
#     * **SaleType** : Type of sale
#     * **SaleCondition** : Condition of sale
#
#
# * Predictive variable:
#     * **SalePrice** - the property's sale price in dollars. This is the target variable that you're trying to predict.
#
# #### Missing
# There are several missing values that are represented in the CSV file as "?"
#
# #### Objective
# Our objective is to produce a good estimator of the house sale price. However, this time we are facing a more complex dataset.
#
# #### Table of contents
# <ol>
#     <li><a href="#preprocessing">Preprocessing</a></li>
#         1.1. <a href="#find_missing">Find missing values</a><br>
#         1.2. <a href="#impute_missing">Impute missing values</a><br>
#     <li><a href="#exploratory_data_analysis">Exploratory data analysis</a></li>
#         2.1. <a href="#univariate_analysis">Univariate analysis</a><br>
#         2.2. <a href="#bivariate_analysis">Bivariate analysis</a><br>
#     <li><a href="#regression_analysis">Regression analysis</a></li>
#         3.1. <a href="#linear_regression">Linear regression</a><br>
#         3.2. <a href="#lasso_regression">Lasso regression</a><br>
#         3.3. <a href="#ridge_regression">Ridge regression</a><br>
#         3.4. <a href="#decision_tree">Decision tree</a><br>
#         3.5. <a href="#knn">KNN</a><br>
#     <li><a href="#estimator_evaluation">Estimator evaluation</a></li>
# </ol>
#
# -----

# %%
import pandas as pd

df = pd.read_csv("ames_housing_train.csv")
df_test_final = pd.read_csv("ames_housing_test.csv")

df = df.drop(columns = ["Id"]) # Drop the ID column (ID of each house)
df_test_final = df_test_final.drop(columns = ["Id"]) # Drop the ID column (ID of each house)

print(df.shape)
print(df_test_final.shape)
# Out:
# (1460, 80)
# (600, 80)

# %% [markdown]
# ## 1 - Preprocessing

# %% [markdown]
# ##### Replace missing values "?" with np.nan

# %%
import numpy as np

df.replace("?", np.nan, inplace = True)
df.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 80 columns]

# %% [markdown]
# ##### Select numeric variables for regression

# %%
df_numeric = df.select_dtypes(exclude="object")
df_test_final = df_test_final.select_dtypes(exclude="object")
print(df_numeric.shape)
print(df_test_final.shape)
# Out:
# (1460, 37)
# (600, 37)

# %% [markdown]
# 37 variables numericas

# %% [markdown]
# ### 1.1 - Find missing values

# %%
missing_data = df_numeric.isnull()
true_counts_percentage = [(column, round(missing_data[column].values.sum() / df_numeric.shape[0], 2)) for column in missing_data.columns]
false_counts_percentage = [(column, round(~missing_data[column].values.sum() / df_numeric.shape[0], 2)) for column in missing_data.columns]
true_counts_percentage.sort(key=lambda x:x[1], reverse = True)
true_counts_percentage
# Out:
# [('LotFrontage', 0.18),
#  ('GarageYrBlt', 0.06),
#  ('MasVnrArea', 0.01),
#  ('MSSubClass', 0.0),
#  ('LotArea', 0.0),
#  ('OverallQual', 0.0),
#  ('OverallCond', 0.0),
#  ('YearBuilt', 0.0),
#  ('YearRemodAdd', 0.0),
#  ('BsmtFinSF1', 0.0),
#  ('BsmtFinSF2', 0.0),
#  ('BsmtUnfSF', 0.0),
#  ('TotalBsmtSF', 0.0),
#  ('1stFlrSF', 0.0),
#  ('2ndFlrSF', 0.0),
#  ('LowQualFinSF', 0.0),
#  ('GrLivArea', 0.0),
#  ('BsmtFullBath', 0.0),
#  ('BsmtHalfBath', 0.0),
#  ('FullBath', 0.0),
#  ('HalfBath', 0.0),
#  ('BedroomAbvGr', 0.0),
#  ('KitchenAbvGr', 0.0),
#  ('TotRmsAbvGrd', 0.0),
#  ('Fireplaces', 0.0),
#  ('GarageCars', 0.0),
#  ('GarageArea', 0.0),
#  ('WoodDeckSF', 0.0),
#  ('OpenPorchSF', 0.0),
#  ('EnclosedPorch', 0.0),
#  ('3SsnPorch', 0.0),
#  ('ScreenPorch', 0.0),
#  ('PoolArea', 0.0),
#  ('MiscVal', 0.0),
#  ('MoSold', 0.0),
#  ('YrSold', 0.0),
#  ('SalePrice', 0.0)]

# %% [markdown]
# * Observamos que **LotFrontage** (superficie de acera) es una variable que tiene bastantes valores missing. Mas especificamente, el 18% de los valores. Dado que es un numero tan alto, consideramos la posibilidad de simplemente eliminar dicha variable.
# * Observamos que **GarageYrBlt** (año en que se construyo el garaje) es una variable que si bien no tiene un porcentage tan alto de misssing values como la anterior, mantiene un porcentage considerable del 6%. En este caso nos encontramos ante varias opciones posibles: eliminar la variable, eliminar ese 6% de instancias o imputar ese 6% de instancias.
# * Observamos que **MasVnrArea** (fachada de ladrillo) es una variable con solo un 0.01% de missing values. En este caso no hay duda de que podriamos imputar estos valores si no quieremos reducir el numero de instancias disponibles para nuestro analisis sin que "perjudique" a la distribucion.

# %% [markdown]
# Por experiencia, prefiero imputar cuando tenemos un numero de instancias tan bajo, asi que en el caso de GarageYrBlt y MasVnrArea, vamos a imputar sus valores. Lo vamos a hacer utilizando el iterativeImputer de Sklearn el cual suele funcionar bastante bien con datos numericos.
#
# <img src="images/comparativa_imputacion.png" width="500">

# %% [markdown]
# ### 1.2 - Impute/Drop missing values

# %%
# Eliminamos la variable LotFrontage, la cual tiene un alto porcentage de missing y 
# tampoco es una variable que a simple vista (vision sesgada) parezca importante
df_numeric = df_numeric.drop(["LotFrontage"], axis="columns")
df_test_final = df_test_final.drop(["LotFrontage"], axis="columns")

# %%
from sklearn.experimental import enable_iterative_imputer  # noqa
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer

# Por simplicidad vamos a utilizar el estimador por defecto (una regresion lineal con regularizacion L2, Ridge)
# Se le puede pasar otro (i.e., un DecisionTreeRegressor, un KNNRegressor, etc.)
imputer = IterativeImputer(missing_values=np.nan,) 
df_numeric_imputed = df_numeric.copy()

# Le puedo pasar todo el dataframe (ya sin la variable LotFrontage) y que el mismo impute aquellas variables
# con missing restantes
#df_numeric_imputed = impute.fit_transform(df_numeric)

# Si queremos seleccionar solo un par de variables (por ejemplo porque queremos usar diferentes metodos de imputacion), 
# hay que tener en cuenta que Sklearn espera siempre que le pasemos un objeto DataFrame, no le vale un objeto Series 
# ni un numpy array, detalles que hacen que nos salgan errores tontos
df_numeric_imputed[["GarageYrBlt", "MasVnrArea"]] = imputer.fit_transform(df_numeric[["GarageYrBlt", "MasVnrArea"]])
df_test_final[["GarageYrBlt", "MasVnrArea"]] = imputer.fit_transform(df_test_final[["GarageYrBlt", "MasVnrArea"]])

# %%
# missing_data_2 = df_numeric_imputed.isnull()
# true_counts_percentage = [(column, round(missing_data_2[column].values.sum() / df_numeric.shape[0], 2)) for column in missing_data_2.columns]
# false_counts_percentage = [(column, round(~missing_data_2[column].values.sum() / df_numeric.shape[0], 2)) for column in missing_data_2.columns]
# true_counts_percentage.sort(key=lambda x:x[1], reverse = True)
# true_counts_percentage

# %% [markdown]
# # 3 - Exploratory data analysis

# %% [markdown]
# ## 3.1 - Univariate analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, (ax1) = plt.subplots(ncols=1, figsize=(6, 4))

x = df_numeric_imputed["SalePrice"]

sns.distplot(x, bins = 20, rug=True);

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## 3.2 - Bivariate analysis

# %% [markdown]
# #### Correlation

# %%
df_numeric_imputed.corr()["SalePrice"].abs().sort_values(ascending=False) # built-in sort function
ordered_columns_corr = df_numeric_imputed.corr()["SalePrice"].abs().sort_values(ascending=False).index
ordered_columns_corr
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt',
#        'YearRemodAdd', 'GarageYrBlt', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1',
#        'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath', 'LotArea',
#        'BsmtFullBath', 'BsmtUnfSF', 'BedroomAbvGr', 'KitchenAbvGr',
#        'EnclosedPorch', 'ScreenPorch', 'PoolArea', 'MSSubClass', 'OverallCond',
#        'MoSold', '3SsnPorch', 'YrSold', 'LowQualFinSF', 'MiscVal',
#        'BsmtHalfBath', 'BsmtFinSF2'],
#       dtype='object')

# %%
import numpy as np

corr = df_numeric_imputed.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# #### Regression plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(ncols=5, nrows=7, figsize=(20, 20))
axs = axs.flatten()

index = 0
for colname in ordered_columns_corr:
    if colname != "SalePrice":
        sns.regplot(ax=axs[index], x=colname, y="SalePrice", data=df_numeric_imputed)
        index += 1
        
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %% [markdown]
# # 3 - Regression analysis

# %%
from sklearn.model_selection import train_test_split

X = df_numeric_imputed.drop(columns=["SalePrice"])
Y = df_numeric_imputed["SalePrice"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=5)

# %%
print(X_train.shape)
print(Y_train.shape) # 1 var, SalePrice
print(X_test.shape)
print(Y_test.shape) # 1 var, SalePrice
# Out:
# (1168, 35)
# (1168,)
# (292, 35)
# (292,)

# %% [markdown]
# ## 3.1 - Linear regression

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %% [markdown]
# ##### One-dimensional linear regression

# %%
from sklearn.model_selection import cross_val_score

X_train_onedim = X_train[["OverallQual"]]
X_test_onedim = X_test[["OverallQual"]]

scores = cross_val_score(lin_reg, X_train_onedim, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.6134395222747401

# %% [markdown]
# ##### Multi-dimensional linear regression

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lin_reg, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.7437731850513597

# %% [markdown]
# Parece que simplemente usar una unica variable no es suficiente para predecir con una regresion lineal el precio de la casa. Utilizando mas de una variable observamos una mejora en el score cross-validado. Ahora nos surge la duda de si es necesario utilizar todas las variables (35) para predecir o si nos podriamos quedar con un subset de las mismas.
#
# La intuicion me dice que hay ciertas variables interesantes para probar asi manualmente, unas pocas que parecen estar correlacionadas con la variable de precio pero no muy correlacionadas entre ellas:
#
# * **OverallQual**
# * **GrLivArea**
# * **FullBath**
# * **GarageCars**

# %% [markdown]
# ##### Multi-dimensional linear regression with manual feature selection

# %%
selected_features = ["OverallQual", "GrLivArea", "FullBath", "GarageCars"]

lin_reg_fs = LinearRegression()
scores = cross_val_score(lin_reg_fs, X_train[selected_features], Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.710823029632959

# %% [markdown]
# ## 3.2 - Ridge regression

# %%
from sklearn.linear_model import Ridge
ridge_reg_1 = Ridge(alpha=1.0) 

scores = cross_val_score(ridge_reg_1, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.7438386980913774

# %%
from sklearn.linear_model import Ridge
ridge_reg_05 = Ridge(alpha=0.5) 

scores = cross_val_score(ridge_reg_05, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.7438065262222675

# %% [markdown]
# ## 3.3 - Lasso regression

# %%
from sklearn.linear_model import Lasso
lasso_reg_1 = Lasso(alpha=1.0) 

scores = cross_val_score(lasso_reg_1, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.7437739540047842

# %%
from sklearn.linear_model import Lasso
lasso_reg_05 = Lasso(alpha=150.5) 

scores = cross_val_score(lasso_reg_05, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.7436699408685794

# %% [markdown]
# En este caso habria que estandarizar para ver su efecto bien, como hay variables con alto numero de diferencia de valores, no se nota casi la regularizaicon, no es capaz e optimizar correctamente

# %% [markdown]
# ## 3.4 - Decision tree

# %%
X_train.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeRegressor

dt_reg = DecisionTreeRegressor(random_state=0, max_depth=30, criterion='squared_error')

scores = cross_val_score(dt_reg, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.651959947967511

# %%
dt_reg.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor(max_depth=30, random_state=0)

# %%
dt_reg.score(X_test, Y_test)
# Out:
# 0.8146351052126257

# %%
# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('once')

# %%
fig, ax = plt.subplots(figsize=(12, 5))

print(f"Profundidad del árbol: {dt_reg.get_depth()}")
print(f"Número de nodos terminales: {dt_reg.get_n_leaves()}")

plot = plot_tree(
            decision_tree = dt_reg,
            feature_names = X_train.columns,
            class_names   = 'Price',
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 3
# Número de nodos terminales: 8

# %%
texto_modelo = export_text(
                    decision_tree = dt_reg,
                    feature_names = list(X_train.columns)
               )
print(texto_modelo)
# Out:
# |--- OverallQual <= 7.50
# |   |--- OverallQual <= 6.50
# |   |   |--- GrLivArea <= 1378.50
# |   |   |   |--- TotalBsmtSF <= 1007.50
# |   |   |   |   |--- BsmtFinSF1 <= 350.50
# |   |   |   |   |   |--- OverallQual <= 4.50
# |   |   |   |   |   |   |--- 1stFlrSF <= 660.50
# |   |   |   |   |   |   |   |--- YearRemodAdd <= 1960.00
# |   |   |   |   |   |   |   |   |--- GarageArea <= 248.00
# |   |   |   |   |   |   |   |   |   |--- EnclosedPorch <= 43.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 123.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [55000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  123.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [60000.00]
# |   |   |   |   |   |   |   |   |   |--- EnclosedPorch >  43.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [68500.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  248.00
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 564.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [35311.00]
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  564.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [40000.00]
# |   |   |   |   |   |   |   |--- YearRemodAdd >  1960.00
# |   |   |   |   |   |   |   |   |--- MoSold <= 6.00
# |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 861.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [75500.00]
# |   |   |   |   |   |   |   |   |   |--- GrLivArea >  861.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [75000.00]
# |   |   |   |   |   |   |   |   |--- MoSold >  6.00
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch <= 72.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [84500.00]
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch >  72.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [86000.00]
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [88000.00]
# |   |   |   |   |   |   |--- 1stFlrSF >  660.50
# |   |   |   |   |   |   |   |--- GarageArea <= 227.00
# |   |   |   |   |   |   |   |   |--- MSSubClass <= 37.50
# |   |   |   |   |   |   |   |   |   |--- YrSold <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1932.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1932.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |   |   |   |--- YrSold >  2006.50
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1937.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1937.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- MSSubClass >  37.50
# |   |   |   |   |   |   |   |   |   |--- OverallCond <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [135000.00]
# |   |   |   |   |   |   |   |   |   |--- OverallCond >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [82000.00]
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- GarageArea >  227.00
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 60.00
# |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 771.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  771.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch <= 70.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch >  70.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  60.00
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1944.50
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [89471.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1944.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1967.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1967.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- OverallQual >  4.50
# |   |   |   |   |   |   |--- GarageArea <= 522.50
# |   |   |   |   |   |   |   |--- BsmtFinSF2 <= 20.50
# |   |   |   |   |   |   |   |   |--- OverallCond <= 5.50
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1925.50
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1268.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1268.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [98000.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1925.50
# |   |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [135000.00]
# |   |   |   |   |   |   |   |   |--- OverallCond >  5.50
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 338.50
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 5635.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  5635.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  338.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1925.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [154900.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1925.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |--- BsmtFinSF2 >  20.50
# |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 827.00
# |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1944.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [95000.00]
# |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1944.50
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 <= 440.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 >  440.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [110000.00]
# |   |   |   |   |   |   |   |   |--- 1stFlrSF >  827.00
# |   |   |   |   |   |   |   |   |   |--- Fireplaces <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1974.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1974.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Fireplaces >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1971.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [134000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1971.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [147000.00]
# |   |   |   |   |   |   |--- GarageArea >  522.50
# |   |   |   |   |   |   |   |--- LotArea <= 4656.50
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 465.00
# |   |   |   |   |   |   |   |   |   |--- value: [173733.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  465.00
# |   |   |   |   |   |   |   |   |   |--- value: [164500.00]
# |   |   |   |   |   |   |   |--- LotArea >  4656.50
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 672.50
# |   |   |   |   |   |   |   |   |   |--- GarageArea <= 564.00
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 121.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [137500.00]
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  121.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [139000.00]
# |   |   |   |   |   |   |   |   |   |--- GarageArea >  564.00
# |   |   |   |   |   |   |   |   |   |   |--- MoSold <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MoSold >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  672.50
# |   |   |   |   |   |   |   |   |   |--- LotArea <= 6613.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [134900.00]
# |   |   |   |   |   |   |   |   |   |--- LotArea >  6613.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 848.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  848.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |--- BsmtFinSF1 >  350.50
# |   |   |   |   |   |--- 1stFlrSF <= 645.00
# |   |   |   |   |   |   |--- BsmtUnfSF <= 118.00
# |   |   |   |   |   |   |   |--- MoSold <= 9.00
# |   |   |   |   |   |   |   |   |--- LowQualFinSF <= 117.00
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 252.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [86000.00]
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  252.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [85400.00]
# |   |   |   |   |   |   |   |   |--- LowQualFinSF >  117.00
# |   |   |   |   |   |   |   |   |   |--- value: [84500.00]
# |   |   |   |   |   |   |   |--- MoSold >  9.00
# |   |   |   |   |   |   |   |   |--- value: [91000.00]
# |   |   |   |   |   |   |--- BsmtUnfSF >  118.00
# |   |   |   |   |   |   |   |--- WoodDeckSF <= 44.00
# |   |   |   |   |   |   |   |   |--- value: [80000.00]
# |   |   |   |   |   |   |   |--- WoodDeckSF >  44.00
# |   |   |   |   |   |   |   |   |--- value: [81000.00]
# |   |   |   |   |   |--- 1stFlrSF >  645.00
# |   |   |   |   |   |   |--- GarageCars <= 1.50
# |   |   |   |   |   |   |   |--- EnclosedPorch <= 227.00
# |   |   |   |   |   |   |   |   |--- OverallCond <= 6.50
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 898.50
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [88000.00]
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  898.50
# |   |   |   |   |   |   |   |   |   |   |--- OverallQual <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- OverallQual >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- OverallCond >  6.50
# |   |   |   |   |   |   |   |   |   |--- LotArea <= 8349.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 441.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  441.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [88000.00]
# |   |   |   |   |   |   |   |   |   |--- LotArea >  8349.50
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- EnclosedPorch >  227.00
# |   |   |   |   |   |   |   |   |--- OverallCond <= 5.50
# |   |   |   |   |   |   |   |   |   |--- value: [62383.00]
# |   |   |   |   |   |   |   |   |--- OverallCond >  5.50
# |   |   |   |   |   |   |   |   |   |--- value: [79000.00]
# |   |   |   |   |   |   |--- GarageCars >  1.50
# |   |   |   |   |   |   |   |--- OverallQual <= 4.50
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 165.50
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 80.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [102000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  80.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [97000.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  165.50
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 257.00
# |   |   |   |   |   |   |   |   |   |   |--- MasVnrArea <= 80.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [120500.00]
# |   |   |   |   |   |   |   |   |   |   |--- MasVnrArea >  80.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [129000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  257.00
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 576.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [110000.00]
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  576.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [111250.00]
# |   |   |   |   |   |   |   |--- OverallQual >  4.50
# |   |   |   |   |   |   |   |   |--- LotArea <= 12300.50
# |   |   |   |   |   |   |   |   |   |--- OverallQual <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 465.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  465.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- OverallQual >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 697.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  697.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- LotArea >  12300.50
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 80.00
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 880.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [143000.00]
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  880.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF >  80.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [180000.00]
# |   |   |   |--- TotalBsmtSF >  1007.50
# |   |   |   |   |--- OverallQual <= 5.50
# |   |   |   |   |   |--- OverallCond <= 4.50
# |   |   |   |   |   |   |--- YearRemodAdd <= 1959.50
# |   |   |   |   |   |   |   |--- value: [60000.00]
# |   |   |   |   |   |   |--- YearRemodAdd >  1959.50
# |   |   |   |   |   |   |   |--- BsmtUnfSF <= 317.50
# |   |   |   |   |   |   |   |   |--- GarageArea <= 392.00
# |   |   |   |   |   |   |   |   |   |--- value: [107000.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  392.00
# |   |   |   |   |   |   |   |   |   |--- value: [108959.00]
# |   |   |   |   |   |   |   |--- BsmtUnfSF >  317.50
# |   |   |   |   |   |   |   |   |--- value: [98600.00]
# |   |   |   |   |   |--- OverallCond >  4.50
# |   |   |   |   |   |   |--- YearBuilt <= 1938.50
# |   |   |   |   |   |   |   |--- LotArea <= 7980.00
# |   |   |   |   |   |   |   |   |--- YrSold <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1134.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1971.42
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [108480.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1971.42
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [107500.00]
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1134.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [109900.00]
# |   |   |   |   |   |   |   |   |--- YrSold >  2008.50
# |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |   |--- LotArea >  7980.00
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 410.50
# |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  410.50
# |   |   |   |   |   |   |   |   |   |--- value: [120000.00]
# |   |   |   |   |   |   |--- YearBuilt >  1938.50
# |   |   |   |   |   |   |   |--- Fireplaces <= 0.50
# |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1974.92
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1176.00
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1102.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  1102.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [84500.00]
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  1176.00
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [179000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1974.92
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 487.00
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1076.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1076.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  487.00
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  1120.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Fireplaces >  0.50
# |   |   |   |   |   |   |   |   |--- OverallCond <= 6.50
# |   |   |   |   |   |   |   |   |   |--- Fireplaces <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 7865.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  7865.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Fireplaces >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- MSSubClass <= 55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MSSubClass >  55.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- OverallCond >  6.50
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1999.50
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1964.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [180500.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1964.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [179900.00]
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1999.50
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1200.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1200.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- OverallQual >  5.50
# |   |   |   |   |   |--- YearBuilt <= 1958.50
# |   |   |   |   |   |   |--- MSSubClass <= 25.00
# |   |   |   |   |   |   |   |--- MasVnrArea <= 155.50
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 696.50
# |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1138.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [136000.00]
# |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1138.00
# |   |   |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [140000.00]
# |   |   |   |   |   |   |   |   |   |   |--- OpenPorchSF >  37.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [139000.00]
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  696.50
# |   |   |   |   |   |   |   |   |   |--- value: [150000.00]
# |   |   |   |   |   |   |   |--- MasVnrArea >  155.50
# |   |   |   |   |   |   |   |   |--- value: [155000.00]
# |   |   |   |   |   |   |--- MSSubClass >  25.00
# |   |   |   |   |   |   |   |--- GarageArea <= 376.00
# |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 6.50
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1935.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [118400.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1935.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [119000.00]
# |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [125000.00]
# |   |   |   |   |   |   |   |--- GarageArea >  376.00
# |   |   |   |   |   |   |   |   |--- value: [110500.00]
# |   |   |   |   |   |--- YearBuilt >  1958.50
# |   |   |   |   |   |   |--- TotalBsmtSF <= 1487.00
# |   |   |   |   |   |   |   |--- GrLivArea <= 1161.50
# |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 233.50
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 960.50
# |   |   |   |   |   |   |   |   |   |   |--- PoolArea <= 288.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- PoolArea >  288.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [171000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  960.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [176000.00]
# |   |   |   |   |   |   |   |   |--- WoodDeckSF >  233.50
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 8089.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [144000.00]
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  8089.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [140000.00]
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [125000.00]
# |   |   |   |   |   |   |   |--- GrLivArea >  1161.50
# |   |   |   |   |   |   |   |   |--- MasVnrArea <= 139.50
# |   |   |   |   |   |   |   |   |   |--- GarageArea <= 598.00
# |   |   |   |   |   |   |   |   |   |   |--- MoSold <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- MoSold >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- GarageArea >  598.00
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [208300.00]
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [196000.00]
# |   |   |   |   |   |   |   |   |--- MasVnrArea >  139.50
# |   |   |   |   |   |   |   |   |   |--- MoSold <= 9.00
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 469.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  469.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- MoSold >  9.00
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [145000.00]
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [142000.00]
# |   |   |   |   |   |   |--- TotalBsmtSF >  1487.00
# |   |   |   |   |   |   |   |--- value: [235000.00]
# |   |   |--- GrLivArea >  1378.50
# |   |   |   |--- BsmtFinSF1 <= 446.00
# |   |   |   |   |--- OverallQual <= 5.50
# |   |   |   |   |   |--- HalfBath <= 0.50
# |   |   |   |   |   |   |--- OverallCond <= 4.50
# |   |   |   |   |   |   |   |--- YearBuilt <= 1955.50
# |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1188.00
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1930.00
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 776.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [79000.00]
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  776.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1930.00
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1949.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [98000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1949.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1188.00
# |   |   |   |   |   |   |   |   |   |--- MSSubClass <= 60.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [104900.00]
# |   |   |   |   |   |   |   |   |   |--- MSSubClass >  60.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [107500.00]
# |   |   |   |   |   |   |   |--- YearBuilt >  1955.50
# |   |   |   |   |   |   |   |   |--- YearBuilt <= 1958.00
# |   |   |   |   |   |   |   |   |   |--- value: [155000.00]
# |   |   |   |   |   |   |   |   |--- YearBuilt >  1958.00
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [134432.00]
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- YrSold <= 2008.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [119000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YrSold >  2008.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |--- OverallCond >  4.50
# |   |   |   |   |   |   |   |--- Fireplaces <= 0.50
# |   |   |   |   |   |   |   |   |--- YearBuilt <= 1905.00
# |   |   |   |   |   |   |   |   |   |--- OverallCond <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 390.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [106000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  390.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- OverallCond >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageCars <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [124000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageCars >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [122500.00]
# |   |   |   |   |   |   |   |   |--- YearBuilt >  1905.00
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 91.00
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1966.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  91.00
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 <= 210.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 >  210.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [117000.00]
# |   |   |   |   |   |   |   |--- Fireplaces >  0.50
# |   |   |   |   |   |   |   |   |--- GarageArea <= 300.00
# |   |   |   |   |   |   |   |   |   |--- value: [108000.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  300.00
# |   |   |   |   |   |   |   |   |   |--- YrSold <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1968.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [172500.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1968.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [169000.00]
# |   |   |   |   |   |   |   |   |   |--- YrSold >  2006.50
# |   |   |   |   |   |   |   |   |   |   |--- MoSold <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MoSold >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- HalfBath >  0.50
# |   |   |   |   |   |   |--- YearBuilt <= 1975.00
# |   |   |   |   |   |   |   |--- FullBath <= 2.50
# |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1737.50
# |   |   |   |   |   |   |   |   |   |--- Fireplaces <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [152000.00]
# |   |   |   |   |   |   |   |   |   |--- Fireplaces >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageCars <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GarageCars >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1737.50
# |   |   |   |   |   |   |   |   |   |--- value: [170000.00]
# |   |   |   |   |   |   |   |--- FullBath >  2.50
# |   |   |   |   |   |   |   |   |--- value: [189000.00]
# |   |   |   |   |   |   |--- YearBuilt >  1975.00
# |   |   |   |   |   |   |   |--- LotArea <= 16117.00
# |   |   |   |   |   |   |   |   |--- value: [197500.00]
# |   |   |   |   |   |   |   |--- LotArea >  16117.00
# |   |   |   |   |   |   |   |   |--- value: [192140.00]
# |   |   |   |   |--- OverallQual >  5.50
# |   |   |   |   |   |--- GarageCars <= 1.50
# |   |   |   |   |   |   |--- YearRemodAdd <= 1956.00
# |   |   |   |   |   |   |   |--- GrLivArea <= 1470.00
# |   |   |   |   |   |   |   |   |--- MoSold <= 2.00
# |   |   |   |   |   |   |   |   |   |--- value: [97500.00]
# |   |   |   |   |   |   |   |   |--- MoSold >  2.00
# |   |   |   |   |   |   |   |   |   |--- value: [89500.00]
# |   |   |   |   |   |   |   |--- GrLivArea >  1470.00
# |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 31.50
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1018.00
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 <= 82.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF2 >  82.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  1018.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |   |   |--- OpenPorchSF >  31.50
# |   |   |   |   |   |   |   |   |   |--- BsmtFullBath <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch <= 15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- EnclosedPorch >  15.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [104000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtFullBath >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [128000.00]
# |   |   |   |   |   |   |--- YearRemodAdd >  1956.00
# |   |   |   |   |   |   |   |--- LotArea <= 9619.00
# |   |   |   |   |   |   |   |   |--- GrLivArea <= 1457.50
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1982.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [165000.00]
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1982.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [153575.00]
# |   |   |   |   |   |   |   |   |--- GrLivArea >  1457.50
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 799.00
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 5805.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [117000.00]
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  5805.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [128000.00]
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  799.00
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [152000.00]
# |   |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- LotArea >  9619.00
# |   |   |   |   |   |   |   |   |--- GarageArea <= 90.00
# |   |   |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  90.00
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1917.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [177000.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1917.00
# |   |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  725.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [169000.00]
# |   |   |   |   |   |--- GarageCars >  1.50
# |   |   |   |   |   |   |--- YearRemodAdd <= 1985.50
# |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1439.00
# |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1245.00
# |   |   |   |   |   |   |   |   |   |--- LotArea <= 11873.00
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 875.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  875.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- LotArea >  11873.00
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1960.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [185000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1960.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1245.00
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea <= 274.50
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1428.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1428.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea >  274.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [158000.00]
# |   |   |   |   |   |   |   |--- TotalBsmtSF >  1439.00
# |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 60.00
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1969.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [185750.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1969.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [185000.00]
# |   |   |   |   |   |   |   |   |--- OpenPorchSF >  60.00
# |   |   |   |   |   |   |   |   |   |--- value: [217000.00]
# |   |   |   |   |   |   |--- YearRemodAdd >  1985.50
# |   |   |   |   |   |   |   |--- YearBuilt <= 1959.00
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 875.50
# |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [207000.00]
# |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [214500.00]
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  875.50
# |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1932.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [240000.00]
# |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1932.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [230000.00]
# |   |   |   |   |   |   |   |--- YearBuilt >  1959.00
# |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 962.00
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1649.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1649.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 860.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  860.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [130000.00]
# |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  962.00
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 952.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [214000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  952.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |--- BsmtFinSF1 >  446.00
# |   |   |   |   |--- GrLivArea <= 1636.00
# |   |   |   |   |   |--- YearRemodAdd <= 1996.50
# |   |   |   |   |   |   |--- LotArea <= 11352.50
# |   |   |   |   |   |   |   |--- OverallQual <= 5.50
# |   |   |   |   |   |   |   |   |--- OverallCond <= 4.50
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1095.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [166000.00]
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  1095.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [150000.00]
# |   |   |   |   |   |   |   |   |--- OverallCond >  4.50
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 547.50
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 11289.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [148000.00]
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  11289.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [144000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  547.50
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1951.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [140000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1951.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- OverallQual >  5.50
# |   |   |   |   |   |   |   |   |--- MoSold <= 4.50
# |   |   |   |   |   |   |   |   |   |--- EnclosedPorch <= 94.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [139000.00]
# |   |   |   |   |   |   |   |   |   |--- EnclosedPorch >  94.50
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFullBath <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [157900.00]
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFullBath >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [153000.00]
# |   |   |   |   |   |   |   |   |--- MoSold >  4.50
# |   |   |   |   |   |   |   |   |   |--- MSSubClass <= 120.00
# |   |   |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- OpenPorchSF >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MSSubClass >  120.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [148500.00]
# |   |   |   |   |   |   |--- LotArea >  11352.50
# |   |   |   |   |   |   |   |--- YearRemodAdd <= 1961.00
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 416.50
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1958.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1955.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [165000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1955.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [166000.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1958.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [157500.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  416.50
# |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1444.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [145250.00]
# |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1444.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [149500.00]
# |   |   |   |   |   |   |   |--- YearRemodAdd >  1961.00
# |   |   |   |   |   |   |   |   |--- MoSold <= 7.50
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 22.00
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 482.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  482.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF >  22.00
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [181900.00]
# |   |   |   |   |   |   |   |   |--- MoSold >  7.50
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 790.50
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 346.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [162000.00]
# |   |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  346.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [158000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  790.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [168000.00]
# |   |   |   |   |   |--- YearRemodAdd >  1996.50
# |   |   |   |   |   |   |--- BsmtFullBath <= 0.50
# |   |   |   |   |   |   |   |--- value: [130500.00]
# |   |   |   |   |   |   |--- BsmtFullBath >  0.50
# |   |   |   |   |   |   |   |--- BedroomAbvGr <= 1.50
# |   |   |   |   |   |   |   |   |--- value: [143000.00]
# |   |   |   |   |   |   |   |--- BedroomAbvGr >  1.50
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 736.50
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [167000.00]
# |   |   |   |   |   |   |   |   |   |--- OpenPorchSF >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- OverallCond >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [176500.00]
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  736.50
# |   |   |   |   |   |   |   |   |   |--- HalfBath <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1465.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [218000.00]
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1465.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- HalfBath >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 537.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [193000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  537.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [197500.00]
# |   |   |   |   |--- GrLivArea >  1636.00
# |   |   |   |   |   |--- LotArea <= 12207.00
# |   |   |   |   |   |   |--- MoSold <= 8.50
# |   |   |   |   |   |   |   |--- MSSubClass <= 80.00
# |   |   |   |   |   |   |   |   |--- GrLivArea <= 2216.00
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1965.50
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt <= 1950.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [175000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageYrBlt >  1950.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [169500.00]
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1965.50
# |   |   |   |   |   |   |   |   |   |   |--- LotArea <= 10287.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- LotArea >  10287.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- GrLivArea >  2216.00
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 112.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [256000.00]
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  112.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [259500.00]
# |   |   |   |   |   |   |   |--- MSSubClass >  80.00
# |   |   |   |   |   |   |   |   |--- LotArea <= 8845.00
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 960.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [151400.00]
# |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  960.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [145000.00]
# |   |   |   |   |   |   |   |   |--- LotArea >  8845.00
# |   |   |   |   |   |   |   |   |   |--- MSSubClass <= 140.00
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 2181.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [188000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GrLivArea >  2181.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |   |   |   |   |   |   |--- MSSubClass >  140.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [160000.00]
# |   |   |   |   |   |   |--- MoSold >  8.50
# |   |   |   |   |   |   |   |--- GarageYrBlt <= 1984.50
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1016.00
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 696.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [172000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  696.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [165500.00]
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  1016.00
# |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 1686.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [167000.00]
# |   |   |   |   |   |   |   |   |   |--- GrLivArea >  1686.00
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 1086.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  1086.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- GarageYrBlt >  1984.50
# |   |   |   |   |   |   |   |   |--- GarageArea <= 548.00
# |   |   |   |   |   |   |   |   |   |--- value: [211000.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  548.00
# |   |   |   |   |   |   |   |   |   |--- value: [193500.00]
# |   |   |   |   |   |--- LotArea >  12207.00
# |   |   |   |   |   |   |--- GarageYrBlt <= 1959.00
# |   |   |   |   |   |   |   |--- YearBuilt <= 1952.00
# |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1993.50
# |   |   |   |   |   |   |   |   |   |--- GrLivArea <= 2226.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [235000.00]
# |   |   |   |   |   |   |   |   |   |--- GrLivArea >  2226.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [239000.00]
# |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1993.50
# |   |   |   |   |   |   |   |   |   |--- value: [243000.00]
# |   |   |   |   |   |   |   |--- YearBuilt >  1952.00
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 519.00
# |   |   |   |   |   |   |   |   |   |--- MoSold <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [256000.00]
# |   |   |   |   |   |   |   |   |   |--- MoSold >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [257500.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  519.00
# |   |   |   |   |   |   |   |   |   |--- value: [277000.00]
# |   |   |   |   |   |   |--- GarageYrBlt >  1959.00
# |   |   |   |   |   |   |   |--- Fireplaces <= 0.50
# |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 799.50
# |   |   |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |   |   |   |   |   |--- 1stFlrSF >  799.50
# |   |   |   |   |   |   |   |   |   |--- OverallCond <= 6.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [150900.00]
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- YearRemodAdd >  2006.50
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 656.50
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  656.50
# |   |   |   |   |   |   |   |   |   |   |--- MSSubClass <= 40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MSSubClass >  40.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [339750.00]
# |   |   |   |   |   |--- WoodDeckSF >  313.50
# |   |   |   |   |   |   |--- GarageArea <= 864.50
# |   |   |   |   |   |   |   |--- value: [372500.00]
# |   |   |   |   |   |   |--- GarageArea >  864.50
# |   |   |   |   |   |   |   |--- value: [395000.00]
# |   |   |   |--- BsmtFinSF1 >  1219.00
# |   |   |   |   |--- GrLivArea <= 1649.00
# |   |   |   |   |   |--- YearRemodAdd <= 2006.00
# |   |   |   |   |   |   |--- EnclosedPorch <= 96.00
# |   |   |   |   |   |   |   |--- BedroomAbvGr <= 2.50
# |   |   |   |   |   |   |   |   |--- value: [275000.00]
# |   |   |   |   |   |   |   |--- BedroomAbvGr >  2.50
# |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 90.00
# |   |   |   |   |   |   |   |   |   |--- value: [270000.00]
# |   |   |   |   |   |   |   |   |--- WoodDeckSF >  90.00
# |   |   |   |   |   |   |   |   |   |--- value: [272000.00]
# |   |   |   |   |   |   |--- EnclosedPorch >  96.00
# |   |   |   |   |   |   |   |--- value: [262000.00]
# |   |   |   |   |   |--- YearRemodAdd >  2006.00
# |   |   |   |   |   |   |--- value: [235000.00]
# |   |   |   |   |--- GrLivArea >  1649.00
# |   |   |   |   |   |--- BedroomAbvGr <= 2.50
# |   |   |   |   |   |   |--- HalfBath <= 0.50
# |   |   |   |   |   |   |   |--- LotArea <= 14434.00
# |   |   |   |   |   |   |   |   |--- YearBuilt <= 2007.50
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea <= 322.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [369900.00]
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea >  322.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [372402.00]
# |   |   |   |   |   |   |   |   |--- YearBuilt >  2007.50
# |   |   |   |   |   |   |   |   |   |--- GarageArea <= 628.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [392500.00]
# |   |   |   |   |   |   |   |   |   |--- GarageArea >  628.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [394617.00]
# |   |   |   |   |   |   |   |--- LotArea >  14434.00
# |   |   |   |   |   |   |   |   |--- value: [440000.00]
# |   |   |   |   |   |   |--- HalfBath >  0.50
# |   |   |   |   |   |   |   |--- LotArea <= 10641.50
# |   |   |   |   |   |   |   |   |--- value: [350000.00]
# |   |   |   |   |   |   |   |--- LotArea >  10641.50
# |   |   |   |   |   |   |   |   |--- LotArea <= 11586.50
# |   |   |   |   |   |   |   |   |   |--- value: [324000.00]
# |   |   |   |   |   |   |   |   |--- LotArea >  11586.50
# |   |   |   |   |   |   |   |   |   |--- value: [316600.00]
# |   |   |   |   |   |--- BedroomAbvGr >  2.50
# |   |   |   |   |   |   |--- OpenPorchSF <= 67.50
# |   |   |   |   |   |   |   |--- GarageYrBlt <= 2005.00
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 426.50
# |   |   |   |   |   |   |   |   |   |--- value: [307000.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  426.50
# |   |   |   |   |   |   |   |   |   |--- value: [305900.00]
# |   |   |   |   |   |   |   |--- GarageYrBlt >  2005.00
# |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 2007.00
# |   |   |   |   |   |   |   |   |   |--- value: [290000.00]
# |   |   |   |   |   |   |   |   |--- YearRemodAdd >  2007.00
# |   |   |   |   |   |   |   |   |   |--- value: [297000.00]
# |   |   |   |   |   |   |--- OpenPorchSF >  67.50
# |   |   |   |   |   |   |   |--- MoSold <= 8.00
# |   |   |   |   |   |   |   |   |--- value: [312500.00]
# |   |   |   |   |   |   |   |--- MoSold >  8.00
# |   |   |   |   |   |   |   |   |--- value: [325624.00]
# |   |   |--- GrLivArea >  2361.50
# |   |   |   |--- GrLivArea <= 3211.00
# |   |   |   |   |--- MasVnrArea <= 338.50
# |   |   |   |   |   |--- LotArea <= 15778.50
# |   |   |   |   |   |   |--- GarageArea <= 539.50
# |   |   |   |   |   |   |   |--- GarageYrBlt <= 1933.00
# |   |   |   |   |   |   |   |   |--- value: [315000.00]
# |   |   |   |   |   |   |   |--- GarageYrBlt >  1933.00
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 919.00
# |   |   |   |   |   |   |   |   |   |--- value: [359100.00]
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  919.00
# |   |   |   |   |   |   |   |   |   |--- value: [345000.00]
# |   |   |   |   |   |   |--- GarageArea >  539.50
# |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1531.00
# |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 1130.00
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1201.50
# |   |   |   |   |   |   |   |   |   |   |--- MoSold <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [285000.00]
# |   |   |   |   |   |   |   |   |   |   |--- MoSold >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [287000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  1201.50
# |   |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [276000.00]
# |   |   |   |   |   |   |   |   |   |   |--- BedroomAbvGr >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [278000.00]
# |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  1130.00
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 1338.50
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [310000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearBuilt >  1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [309000.00]
# |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  1338.50
# |   |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF <= 1483.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- 2ndFlrSF >  1483.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [299800.00]
# |   |   |   |   |   |   |   |--- BsmtUnfSF >  1531.00
# |   |   |   |   |   |   |   |   |--- value: [340000.00]
# |   |   |   |   |   |--- LotArea >  15778.50
# |   |   |   |   |   |   |--- TotalBsmtSF <= 1324.00
# |   |   |   |   |   |   |   |--- YrSold <= 2006.50
# |   |   |   |   |   |   |   |   |--- value: [260000.00]
# |   |   |   |   |   |   |   |--- YrSold >  2006.50
# |   |   |   |   |   |   |   |   |--- value: [267000.00]
# |   |   |   |   |   |   |--- TotalBsmtSF >  1324.00
# |   |   |   |   |   |   |   |--- value: [235000.00]
# |   |   |   |   |--- MasVnrArea >  338.50
# |   |   |   |   |   |--- GrLivArea <= 2712.00
# |   |   |   |   |   |   |--- WoodDeckSF <= 316.50
# |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 760.50
# |   |   |   |   |   |   |   |   |--- YearBuilt <= 2003.50
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [290000.00]
# |   |   |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [285000.00]
# |   |   |   |   |   |   |   |   |--- YearBuilt >  2003.50
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1150.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [317000.00]
# |   |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  1150.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [325300.00]
# |   |   |   |   |   |   |   |--- BsmtFinSF1 >  760.50
# |   |   |   |   |   |   |   |   |--- GrLivArea <= 2621.00
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea <= 548.00
# |   |   |   |   |   |   |   |   |   |   |--- YrSold <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [348000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YrSold >  2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [354000.00]
# |   |   |   |   |   |   |   |   |   |--- MasVnrArea >  548.00
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [340000.00]
# |   |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- GrLivArea >  2621.00
# |   |   |   |   |   |   |   |   |   |--- value: [315000.00]
# |   |   |   |   |   |   |--- WoodDeckSF >  316.50
# |   |   |   |   |   |   |   |--- TotRmsAbvGrd <= 9.00
# |   |   |   |   |   |   |   |   |--- value: [402000.00]
# |   |   |   |   |   |   |   |--- TotRmsAbvGrd >  9.00
# |   |   |   |   |   |   |   |   |--- value: [361919.00]
# |   |   |   |   |   |--- GrLivArea >  2712.00
# |   |   |   |   |   |   |--- BsmtFinSF1 <= 919.50
# |   |   |   |   |   |   |   |--- value: [403000.00]
# |   |   |   |   |   |   |--- BsmtFinSF1 >  919.50
# |   |   |   |   |   |   |   |--- value: [424870.00]
# |   |   |   |--- GrLivArea >  3211.00
# |   |   |   |   |--- YearRemodAdd <= 2000.00
# |   |   |   |   |   |--- 1stFlrSF <= 2010.50
# |   |   |   |   |   |   |--- value: [381000.00]
# |   |   |   |   |   |--- 1stFlrSF >  2010.50
# |   |   |   |   |   |   |--- YrSold <= 2008.50
# |   |   |   |   |   |   |   |--- value: [430000.00]
# |   |   |   |   |   |   |--- YrSold >  2008.50
# |   |   |   |   |   |   |   |--- value: [410000.00]
# |   |   |   |   |--- YearRemodAdd >  2000.00
# |   |   |   |   |   |--- value: [538000.00]
# |   |--- OverallQual >  8.50
# |   |   |--- PoolArea <= 517.50
# |   |   |   |--- BsmtFinSF1 <= 2224.00
# |   |   |   |   |--- GrLivArea <= 2229.00
# |   |   |   |   |   |--- GarageCars <= 2.50
# |   |   |   |   |   |   |--- OpenPorchSF <= 119.00
# |   |   |   |   |   |   |   |--- GrLivArea <= 1760.50
# |   |   |   |   |   |   |   |   |--- value: [325000.00]
# |   |   |   |   |   |   |   |--- GrLivArea >  1760.50
# |   |   |   |   |   |   |   |   |--- value: [318061.00]
# |   |   |   |   |   |   |--- OpenPorchSF >  119.00
# |   |   |   |   |   |   |   |--- GarageArea <= 647.00
# |   |   |   |   |   |   |   |   |--- value: [264132.00]
# |   |   |   |   |   |   |   |--- GarageArea >  647.00
# |   |   |   |   |   |   |   |   |--- value: [239000.00]
# |   |   |   |   |   |--- GarageCars >  2.50
# |   |   |   |   |   |   |--- 1stFlrSF <= 2028.00
# |   |   |   |   |   |   |   |--- BsmtUnfSF <= 445.00
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 <= 1245.00
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1296.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [335000.00]
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1296.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [350000.00]
# |   |   |   |   |   |   |   |   |--- BsmtFinSF1 >  1245.00
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1817.00
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 1724.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [367294.00]
# |   |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1724.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  1817.00
# |   |   |   |   |   |   |   |   |   |   |--- FullBath <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [385000.00]
# |   |   |   |   |   |   |   |   |   |   |--- FullBath >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- BsmtUnfSF >  445.00
# |   |   |   |   |   |   |   |   |--- GarageArea <= 689.00
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 186.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [377426.00]
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  186.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [370878.00]
# |   |   |   |   |   |   |   |   |--- GarageArea >  689.00
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd <= 2003.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [285000.00]
# |   |   |   |   |   |   |   |   |   |--- YearRemodAdd >  2003.00
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea <= 738.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [360000.00]
# |   |   |   |   |   |   |   |   |   |   |--- GarageArea >  738.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- 1stFlrSF >  2028.00
# |   |   |   |   |   |   |   |--- GarageYrBlt <= 2006.50
# |   |   |   |   |   |   |   |   |--- value: [465000.00]
# |   |   |   |   |   |   |   |--- GarageYrBlt >  2006.50
# |   |   |   |   |   |   |   |   |--- YrSold <= 2007.50
# |   |   |   |   |   |   |   |   |   |--- value: [415298.00]
# |   |   |   |   |   |   |   |   |--- YrSold >  2007.50
# |   |   |   |   |   |   |   |   |   |--- value: [385000.00]
# |   |   |   |   |--- GrLivArea >  2229.00
# |   |   |   |   |   |--- YearBuilt <= 2007.50
# |   |   |   |   |   |   |--- GrLivArea <= 2821.50
# |   |   |   |   |   |   |   |--- BsmtFullBath <= 0.50
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF <= 1773.00
# |   |   |   |   |   |   |   |   |   |--- YearBuilt <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1315.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [325000.00]
# |   |   |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  1315.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [333168.00]
# |   |   |   |   |   |   |   |   |   |--- YearBuilt >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [342643.00]
# |   |   |   |   |   |   |   |   |--- BsmtUnfSF >  1773.00
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF <= 2230.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [380000.00]
# |   |   |   |   |   |   |   |   |   |--- 1stFlrSF >  2230.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [386250.00]
# |   |   |   |   |   |   |   |--- BsmtFullBath >  0.50
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF <= 2240.50
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF <= 298.00
# |   |   |   |   |   |   |   |   |   |   |--- OverallQual <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [437154.00]
# |   |   |   |   |   |   |   |   |   |   |--- OverallQual >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [426000.00]
# |   |   |   |   |   |   |   |   |   |--- WoodDeckSF >  298.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [412500.00]
# |   |   |   |   |   |   |   |   |--- TotalBsmtSF >  2240.50
# |   |   |   |   |   |   |   |   |   |--- value: [466500.00]
# |   |   |   |   |   |   |--- GrLivArea >  2821.50
# |   |   |   |   |   |   |   |--- TotalBsmtSF <= 1549.50
# |   |   |   |   |   |   |   |   |--- value: [475000.00]
# |   |   |   |   |   |   |   |--- TotalBsmtSF >  1549.50
# |   |   |   |   |   |   |   |   |--- value: [556581.00]
# |   |   |   |   |   |--- YearBuilt >  2007.50
# |   |   |   |   |   |   |--- MoSold <= 5.50
# |   |   |   |   |   |   |   |--- ScreenPorch <= 85.00
# |   |   |   |   |   |   |   |   |--- value: [611657.00]
# |   |   |   |   |   |   |   |--- ScreenPorch >  85.00
# |   |   |   |   |   |   |   |   |--- HalfBath <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [555000.00]
# |   |   |   |   |   |   |   |   |--- HalfBath >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [582933.00]
# |   |   |   |   |   |   |--- MoSold >  5.50
# |   |   |   |   |   |   |   |--- YrSold <= 2008.50
# |   |   |   |   |   |   |   |   |--- value: [446261.00]
# |   |   |   |   |   |   |   |--- YrSold >  2008.50
# |   |   |   |   |   |   |   |   |--- OpenPorchSF <= 69.00
# |   |   |   |   |   |   |   |   |   |--- value: [501837.00]
# |   |   |   |   |   |   |   |   |--- OpenPorchSF >  69.00
# |   |   |   |   |   |   |   |   |   |--- value: [485000.00]
# |   |   |   |--- BsmtFinSF1 >  2224.00
# |   |   |   |   |--- LotArea <= 51990.50
# |   |   |   |   |   |--- value: [184750.00]
# |   |   |   |   |--- LotArea >  51990.50
# |   |   |   |   |   |--- value: [160000.00]
# |   |   |--- PoolArea >  517.50
# |   |   |   |--- value: [745000.00]

# %%
importancia_predictores = pd.DataFrame(
                            {'predictor': list(X_train.columns),
                             'importancia': dt_reg.feature_importances_}
                            )
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores.sort_values('importancia', ascending=False)
# Out:
# Importancia de los predictores en el modelo
# -------------------------------------------
#         predictor   importancia
# 2     OverallQual  6.599774e-01
# 14      GrLivArea  1.079125e-01
# 7      BsmtFinSF1  5.103193e-02
# 10    TotalBsmtSF  3.240186e-02
# 31       PoolArea  1.769639e-02
# 25     GarageArea  1.719085e-02
# 1         LotArea  1.602370e-02
# 4       YearBuilt  1.554297e-02
# 5    YearRemodAdd  1.195695e-02
# 33         MoSold  7.502504e-03
# 11       1stFlrSF  7.317332e-03
# 24     GarageCars  6.863675e-03
# 26     WoodDeckSF  6.735867e-03
# 9       BsmtUnfSF  5.031568e-03
# 22     Fireplaces  4.851768e-03
# 3     OverallCond  4.500519e-03
# 23    GarageYrBlt  3.969154e-03
# 6      MasVnrArea  3.563652e-03
# 15   BsmtFullBath  3.055334e-03
# 19   BedroomAbvGr  2.678348e-03
# 0      MSSubClass  2.492737e-03
# 18       HalfBath  2.409281e-03
# 8      BsmtFinSF2  1.895419e-03
# 27    OpenPorchSF  1.856992e-03
# 12       2ndFlrSF  1.651545e-03
# 28  EnclosedPorch  1.188223e-03
# 34         YrSold  1.014553e-03
# 21   TotRmsAbvGrd  6.285781e-04
# 13   LowQualFinSF  5.398508e-04
# 17       FullBath  2.887105e-04
# 30    ScreenPorch  2.159659e-04
# 32        MiscVal  9.654405e-06
# 29      3SsnPorch  3.515007e-06
# 20   KitchenAbvGr  5.477489e-07
# 16   BsmtHalfBath  1.511267e-07

# %%
selected_features
# Out:
# ['OverallQual', 'GrLivArea', 'FullBath', 'GarageCars']

# %%
s_features = ['OverallQual', 'GrLivArea', 'BsmtFinSF1', 'TotalBsmtSF']

# %%
from sklearn.tree import DecisionTreeRegressor

dt_reg_fs = DecisionTreeRegressor(random_state=0)

scores = cross_val_score(dt_reg_fs, X_train[s_features], Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.662139062733514

# %%
dt_reg_fs.fit(X_train[s_features],Y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
fig, ax = plt.subplots(figsize=(12, 5))

print(f"Profundidad del árbol: {dt_reg_fs.get_depth()}")
print(f"Número de nodos terminales: {dt_reg_fs.get_n_leaves()}")

plot = plot_tree(
            decision_tree = dt_reg_fs,
            feature_names = s_features,
            class_names   = 'Price',
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 23
# Número de nodos terminales: 1129

# %%
# Espacio de búsqueda de cada hiperparámetro
param_distributions = {'max_depth': np.linspace(1, 32, 20, dtype=int)}

# %%
import sklearn

# %%
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
# Búsqueda random grid
grid = RandomizedSearchCV(
        estimator  = DecisionTreeRegressor(),
        param_distributions = param_distributions,
        n_iter     = 20,
        scoring    = 'r2',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits = 5, n_repeats = 3), 
        refit      = True, 
        verbose    = 0,
        random_state = 123,
        return_train_score = True
       )

grid.fit(X = X_train, y = Y_train)

# Resultados del grid
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False)\
    .head(1)
# Out:
#   param_max_depth  mean_test_score  std_test_score  mean_train_score  \
# 2               4         0.699591        0.082243           0.81402
#
#    std_train_score
# 2          0.00477

# %%
fig, ax = plt.subplots(figsize=(6, 3.84))
hiperparametro = 'param_max_depth'
resultados = resultados.sort_values(hiperparametro, ascending = False)
metrica    = grid.scoring

resultados.plot(hiperparametro, 'mean_train_score', ax=ax)
resultados.plot(hiperparametro, 'mean_test_score', ax=ax)
ax.fill_between(resultados[hiperparametro].astype(np.int),
                resultados['mean_train_score'] + resultados['std_train_score'],
                resultados['mean_train_score'] - resultados['std_train_score'],
                alpha=0.2)
ax.fill_between(resultados[hiperparametro].astype(np.int),
                resultados['mean_test_score'] + resultados['std_test_score'],
                resultados['mean_test_score'] - resultados['std_test_score'],
                alpha=0.2)
ax.legend()
ax.set_title('Evolución del error CV')
ax.set_ylabel(metrica);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## 3.5 - KNN

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg_3 = KNeighborsRegressor(n_neighbors=3)
scores = cross_val_score(knn_reg_3, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.6425895504928478

# %%
knn_reg_3.weights
# Out:
# 'uniform'

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg_5 = KNeighborsRegressor(n_neighbors=5)
scores = cross_val_score(knn_reg_5, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.6574296644697877

# %%
from sklearn.model_selection import RandomizedSearchCV, RepeatedKFold

# %%
import multiprocessing

# %%
param_distributions = {'n_neighbors': np.linspace(1, 10, 20, dtype=int)}

# Búsqueda random grid
grid = RandomizedSearchCV(
        estimator  = KNeighborsRegressor(),
        param_distributions = param_distributions,
        n_iter     = 20,
        scoring    = 'r2',
        n_jobs     = multiprocessing.cpu_count() - 1,
        cv         = RepeatedKFold(n_splits = 5, n_repeats = 3), 
        refit      = True, 
        verbose    = 0,
        random_state = 123,
        return_train_score = True
       )

grid.fit(X = X_train, y = Y_train)

# Resultados del grid
# ==============================================================================
resultados = pd.DataFrame(grid.cv_results_)
resultados.filter(regex = '(param.*|mean_t|std_t)')\
    .drop(columns = 'params')\
    .sort_values('mean_test_score', ascending = False)\
    .head(1)
# Out:
#    param_n_neighbors  mean_test_score  std_test_score  mean_train_score  \
# 14                 7         0.653045        0.028879          0.745431
#
#     std_train_score
# 14          0.00774

# %%
fig, ax = plt.subplots(figsize=(6, 3.84))
hiperparametro = 'param_n_neighbors'
resultados = resultados.sort_values(hiperparametro, ascending = False)
metrica    = grid.scoring

resultados.plot(hiperparametro, 'mean_train_score', ax=ax)
resultados.plot(hiperparametro, 'mean_test_score', ax=ax)
ax.fill_between(resultados[hiperparametro].astype(np.int),
                resultados['mean_train_score'] + resultados['std_train_score'],
                resultados['mean_train_score'] - resultados['std_train_score'],
                alpha=0.2)
ax.fill_between(resultados[hiperparametro].astype(np.int),
                resultados['mean_test_score'] + resultados['std_test_score'],
                resultados['mean_test_score'] - resultados['std_test_score'],
                alpha=0.2)
ax.legend()
ax.set_title('Evolución del error CV')
ax.set_ylabel(metrica);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg_3 = KNeighborsRegressor(n_neighbors=3)
scores = cross_val_score(knn_reg_3, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.6425895504928478

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg_3 = KNeighborsRegressor(n_neighbors=3)
scores = cross_val_score(knn_reg_3, X_train, Y_train, cv=10) # By default we use the R2 score
print("Cross-val score: " + str(scores.mean()))
# Out:
# Cross-val score: 0.6425895504928478

# %% [markdown]
# # 4 - Estimator evaluation

# %%
lin_reg_fitted = lin_reg.fit(X_train, Y_train)
lin_reg_fs_fitted = lin_reg_fs.fit(X_train[selected_features], Y_train)
ridge_reg_fitted = ridge_reg_05.fit(X_train, Y_train)
lasso_reg_fitted = lasso_reg_05.fit(X_train, Y_train)
dt_reg_fitted = dt_reg.fit(X_train, Y_train)
dt_reg_fs_fitted = dt_reg_fs.fit(X_train[selected_features], Y_train)
knn_fitted = knn_reg_5.fit(X_train, Y_train)

# %% [markdown]
# ## 4.1 - Our test

# %%
print("Linear regression score: " + str(lin_reg_fitted.score(X_test, Y_test)))
print("Linear regression with manual FS score: " + str(lin_reg_fs_fitted.score(X_test[selected_features], Y_test)))
print("Ridge regression score: "+ str(ridge_reg_fitted.score(X_test, Y_test)))
print("Lasso regression score: "+ str(lasso_reg_fitted.score(X_test, Y_test)))
print("Decision tree score: " + str(dt_reg_fitted.score(X_test, Y_test)))
print("Decision tree manual FS score: " + str(dt_reg_fs_fitted.score(X_test[selected_features], Y_test)))
print("KNN score: " + str(knn_fitted.score(X_test, Y_test)))
# Out:
# Linear regression score: 0.8292656028567812
# Linear regression with manual FS score: 0.7682844366306061
# Ridge regression score: 0.8293071304053086
# Lasso regression score: 0.8316317952500021
# Decision tree score: 0.7789821904739621
# Decision tree manual FS score: 0.6856433745135556
# KNN score: 0.5588737760069409

# %% [markdown]
# ## 4.2 - Extra test

# %%
X_test_final = df_test_final.drop(["SalePrice"], axis="columns")
Y_test_final = df_test_final["SalePrice"]

# %%
print("Linear regression score: " + str(lin_reg_fitted.score(X_test_final, Y_test_final)))
print("Linear regression with manual FS score: " + str(lin_reg_fs_fitted.score(X_test_final[selected_features], Y_test_final)))
print("Ridge regression score: "+ str(ridge_reg_fitted.score(X_test_final, Y_test_final)))
print("Lasso regression score: "+ str(lasso_reg_fitted.score(X_test_final, Y_test_final)))
print("Decision tree score: " + str(dt_reg_fitted.score(X_test_final, Y_test_final)))
print("Decision tree manual FS score: " + str(dt_reg_fs_fitted.score(X_test_final[selected_features], Y_test_final)))
print("KNN score: " + str(knn_fitted.score(X_test_final, Y_test_final)))
# Out:
# Linear regression score: 0.7676557561300204
# Linear regression with manual FS score: 0.7014272631887258
# Ridge regression score: 0.7676122740848939
# Lasso regression score: 0.7664349177627499
# Decision tree score: 0.9635129391867913
# Decision tree manual FS score: 0.9111151537399106
# KNN score: 0.7774763167273594
